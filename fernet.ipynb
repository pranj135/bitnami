# %% [markdown]
# <a href="https://colab.research.google.com/github/pranj135/bitnami/blob/main/fernet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import wave
# import required module
from cryptography.fernet import Fernet
from cryptography.fernet import Fernet

# %%
key = Fernet.generate_key()

# %%
with open('filekey.key', 'wb') as filekey:
    filekey.write(key)

# %%
def case(a):
    if a == 1:
        encode()
    elif a == 2:
        decode()
    elif a == 3:
        quit()
    else:
        print("\nEnter valid Choice!")

# %%
from cryptography.fernet import Fernet
import wave

def encode():
    print("\nEncoding Starts..")

    audio = wave.open(r"audiocheck.net_pinknoise.wav", mode="rb")
    frame_bytes = bytearray(list(audio.readframes(audio.getnframes())))
    string = str(input("Enter Text to be Encrypted : "))
    string = string + int((len(frame_bytes)-(len(string)*8*8))/8) * '#'
    bits = list(map(int, ''.join([bin(ord(i)).lstrip('0b').rjust(8, '0') for i in string])))
    for i, bit in enumerate(bits):
        frame_bytes[i] = (frame_bytes[i] & 254) | bit
    frame_modified = bytes(frame_bytes)
    for i in range(0, 10):
        print(frame_bytes[i])
    newAudio = wave.open('Audio_1.wav', 'wb')
    newAudio.setparams(audio.getparams())
    newAudio.writeframes(frame_modified)
    newAudio.close()
    audio.close()
    print(" |----> Successfully encoded inside Audio_1.wav")
    print("Applying Fernet Algorithm to Encrypt Audio 1 file ")
    # opening the key
    with open('filekey.key', 'rb') as filekey:
        key = filekey.read()
    # using the generated key
    fernet = Fernet(key)
    # opening the original file to encrypt
    with open('Audio_1.wav', 'rb') as file:
        original = file.read()
    # encrypting the file
    encrypted = fernet.encrypt(original)
    # opening the file in write mode and
    # writing the encrypted data
    with open('Audio_1.wav', 'wb') as encrypted_file:
        encrypted_file.write(encrypted)
    print("Audio file encrypted with Fernet Algorithm Successful ")

# %%
def decode():
    print("Audio file decryption with Fernet Algorithm Starts:")

    # using the key
    fernet = Fernet(key)

    # opening the encrypted file
    with open('Audio_1.wav', 'rb') as enc_file:
        encrypted = enc_file.read()
        print(encrypted)

    # decrypting the file
    decrypted = fernet.decrypt(encrypted)

    # opening the file in write mode and writing the decrypted data
    with open('Audio_1.wav', 'wb') as dec_file:
        dec_file.write(decrypted)

    print("Audio file decryption with Fernet Algorithm Successful")
    print("\nDecoding Starts: Steganography ")

    audio = wave.open("Audio_1.wav", mode='rb')
    frame_bytes = bytearray(list(audio.readframes(audio.getnframes())))
    extracted = [frame_bytes[i] & 1 for i in range(len(frame_bytes))]
    string = "".join(chr(int("".join(map(str, extracted[i:i+8])), 2)) for i in range(0, len(extracted), 8))
    decoded = string.split("###")[0]
    print("Successfully decoded: "+decoded)
    audio.close()

# %%
def main():
     while (1):
        print("\nSelect an option: \n1)Encode\n2)Decode\n3)exit")
        val = int(input("\nChoice:"))
        case(val)
if __name__ == "__main__":
    main()
# Out:
# Select an option:
# 1)Encode
# 2)Decode
# 3)exit
#
# Encoding Starts..
# 0
# 1
# 155
# 0
# 199
# 0
# 36
# 0
# 120
# 1
#  |----> Successfully encoded inside Audio_1.wav
# Applying Fernet Algorithm to Encrypt Audio 1 file
# Audio file encrypted with Fernet Algorithm Successful
#
# Select an option:
# 1)Encode
# 2)Decode
# 3)exit
# Audio file decryption with Fernet Algorithm Starts:
# b'gAAAAABmFOsAPLpQ6n1jl5zgXqpBWusRPle3rCJL0agVFwoQh0jfhulv0kUxYI1jV25mF4fNN9ucY8XIQw2a_kRL8e7LWep0O0Cv4knThj3i8dplwZr4iOzx_1-9l4I_SslfPvM4erNKYBPv-HVi8oylU44qxJTxQVAUVjitE7cILfU6AX2qOYsbI-kQ0xKjjNJIryjud59Sv15NgKw6s3JZclcM1sNmqToNdjxwQeiqK5auhfVfTk6UMMVWOlsgu5x6Ci0QFamL0nXt5RApGdijAx4oQAQAFCXWfojwYChTcfStju0quOVxhXCig5G8dJ0BnzX6ON7TG3GkUEZDXKkAs9Dy4zKQruiWM5da0bYu6Y5_c0C2-A3VmP0TAwWAHWZ6H_4N1gYDfZfU50O38T2kKtoPPF-aqbMw_L8o2_mgT5ZH5l3JfjEsu7F9irodR_nPawT7tN87RAh5foYK8VRSoPge_P4jPKpdC7nb_ej2B2Lc_UjkV7DLMOX0JyCn8m2pcHJMF1HAvxiw-kBbLgMnkzNfNNEJlkdg0NuJk0pMySkFmDC3Xxq_slLFQhb2PZ145QZD7MzEjCq2-3VxHyT7eI40M1YqwD32QJPUwVYMMWQRBjV8gWHvJoGvVoSULWRATB4LGITsY3nIoqkwtksDQmPj3p-olO05BKRKJ15zYtPopDAfN1-46IRB3AYEWcoLOe2Dfw5UM3MHQ-pK_HtEjgziV7U94ZobZTaPIJ9YIVSX2a-bFo5P5zwjLGltdzf0M_MWNqdTu3FIU7PVHOX5rlmj5HG13HQR9zaQXZIDVpOT11AncZqkMnA9KkcWJrTdWme1N91CO2plsxPqNw08F3JtY_tR9PJaKUeE4zoepzNSeoe7i7VxUIsVC95FdFZ53DLbHk_sDYINaNMxgcjN7VPFWwUKz70c2XYCgnKTy7hH7ak9EiWoyGsA5RrXTYQjVBx-izfSR0lMCbP-uklzIKVxmTF0MHdg5RblprVOAT90GMdeRrYfjTRRI570pkkO_RzAcYxOXdaQihx-fTYTTioYKfMzRMoEig0C5TJQWFU0kl8mOl7nJoLXm7jtWYltKED4bYLamMqiuyYURXf75O9wS8_bqrgT1FgGCCADRmz2AYXbWRRqe0y53f1P2dx8tO3BXqVu6zDyRsIUsrb9rGXhY8G1O-p1cZ8o1DLq6ZsqpMXG6lAFe